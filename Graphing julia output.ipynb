# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
# Out:
# /Users/jonathan

# %%
df = pd.read_csv("/Users/jonathan/Desktop/DTU/Kandidat/Battery Project/JuliaCode/alldata.csv")

# %%
df
# Out:
#                     times  da_price  id_prices  z_id_ch  z_id_dis  z_da_ch  \
# 0     2019-03-17 00:00:00     55.01      38.17      1.0       0.0      0.0
# 1     2019-03-17 00:30:00     55.01      39.71      1.0       0.0      0.0
# 2     2019-03-17 01:00:00     49.00      42.81      1.0       0.0      0.0
# 3     2019-03-17 01:30:00     49.00      34.63      1.0       0.0      0.0
# 4     2019-03-17 02:00:00     39.48      32.81      1.0       0.0      0.0
# ...                   ...       ...        ...      ...       ...      ...
# 2875  2019-05-15 21:30:00     37.50      38.78      0.0       1.0      1.0
# 2876  2019-05-15 22:00:00     44.42      37.31      1.0       0.0      0.0
# 2877  2019-05-15 22:30:00     44.42      36.11      1.0       0.0      0.0
# 2878  2019-05-15 23:00:00     33.00      43.94      0.0       1.0      1.0
# 2879  2019-05-15 23:30:00     33.00      47.81      0.0       1.0      1.0
#
# ...

# %%
plt.plot(df.times[0:100],df.da_price[0:100])
plt.plot(df.times[0:100],df.id_prices[0:100])
plt.plot(df.times[0:100],df.SOC[0:100]*100-100)

# %%
p3 = plt.plot(df.times[0:100],df.da_price[0:100])
p2 = plt.plot(df.times[0:100],df.id_prices[0:100])
p1 = plt.plot(df.times[0:100],df.SOC[0:100]*100-100)
plt.xticks(range(0, len(df.times), 10), df.times[::10]);

# %%
X_TICKS = 100 # use every 4th value; change this number until you like the result

times=df.times[0:500]
predictions=df.da_price[0:500]
rvpredictions=df.SOC[0:500]*100-120
plt.title('SOC and DA prices')
plt.plot(predictions, '--', color='darkred', label='DA Prices')
plt.plot(rvpredictions, '--', color='darkorange', label='SOC')
plt.legend()
plt.ylim(-120, 120)
plt.xticks(range(0, len(times), X_TICKS), times[::X_TICKS], rotation = 90)
plt.tight_layout() # auto adjust the spacing around the graph
plt.show()

# %%
profit = 0
for i in range(3*48):
    profit_da = df.da_price[i]*(1/2)*(df.p_da_dis[i]-df.p_da_ch[i])
    profit_id = df.id_prices[i]*(1/2)*(df.p_id_dis[i]-df.p_id_ch[i])
    profit = profit + profit_da + profit_id
print(profit)
# Out:
# 361.28440347826086

# %%
plt.plot(df.times,df.da_price)
plt.plot(df.times,df.id_prices)
plt.plot(df.times,150*df.p_id_ch)
plt.plot(df.times,150*df.p_id_dis)
plt.plot(df.times,150*df.p_da_ch)
plt.plot(df.times,150*df.p_da_dis)
